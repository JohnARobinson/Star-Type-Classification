# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
# %matplotlib inline
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

# %%
dfstar = pd.read_csv("desktop/Stars.csv")

# %%
dfstar.columns
# Out:
# Index(['Temperature', 'L', 'R', 'A_M', 'Color', 'Spectral_Class', 'Type'], dtype='object')

# %%
dfstar.head
# Out:
# <bound method NDFrame.head of      Temperature          L        R     A_M  Color  Spectral_Class  Type
# 0           3068      0.002    0.170  16.120    Red               6     0
# 1           3042      0.001    0.154  16.600    Red               6     0
# 2           2600      0.000    0.102  18.700    Red               6     0
# 3           2800      0.000    0.160  16.650    Red               6     0
# 4           1939      0.000    0.103  20.060    Red               6     0
# ..           ...        ...      ...     ...    ...             ...   ...
# 235        38940 374830.000 1356.000  -9.930   Blue               0     5
# 236        30839 834042.000 1194.000 -10.630   Blue               0     5
# 237         8829 537493.000 1423.000 -10.730  White               2     5
# 238         9235 404940.000 1112.000 -11.230  White               2     5
# 239        37882 294903.000 1783.000  -7.800   Blue               0     5
#
# [240 rows x 7 columns]>

# %%
dfstar.info
# Out:
# <bound method DataFrame.info of      Temperature          L        R     A_M  Color Spectral_Class  Type
# 0           3068      0.002    0.170  16.120    Red              M     0
# 1           3042      0.001    0.154  16.600    Red              M     0
# 2           2600      0.000    0.102  18.700    Red              M     0
# 3           2800      0.000    0.160  16.650    Red              M     0
# 4           1939      0.000    0.103  20.060    Red              M     0
# ..           ...        ...      ...     ...    ...            ...   ...
# 235        38940 374830.000 1356.000  -9.930   Blue              O     5
# 236        30839 834042.000 1194.000 -10.630   Blue              O     5
# 237         8829 537493.000 1423.000 -10.730  White              A     5
# 238         9235 404940.000 1112.000 -11.230  White              A     5
# 239        37882 294903.000 1783.000  -7.800   Blue              O     5
#
# [240 rows x 7 columns]>

# %%
dfstar.hist(bins=50, figsize=(20,15))
plt.show()

# %%
dfstar['Temperature'].describe()
# Out:
# count     240.000
# mean    10497.462
# std      9552.425
# min      1939.000
# 25%      3344.250
# 50%      5776.000
# 75%     15055.500
# max     40000.000
# Name: Temperature, dtype: float64

# %%
dfstar['L'].describe()
# Out:
# count      240.000
# mean    107188.362
# std     179432.245
# min          0.000
# 25%          0.001
# 50%          0.071
# 75%     198050.000
# max     849420.000
# Name: L, dtype: float64

# %%
dfstar['Type'].describe()
# Out:
# count   240.000
# mean      2.500
# std       1.711
# min       0.000
# 25%       1.000
# 50%       2.500
# 75%       4.000
# max       5.000
# Name: Type, dtype: float64

# %%
sns.distplot(dfstar['Temperature']);
# Out:
# C:\Users\Rex Reloaded\anaconda3\envs\virtualenv\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print("Skewness: %f" % df_star['Temperature'].skew())
print("Kurtosis: %f" % df_star['Temperature'].kurt())
# Out:
# Skewness: 1.321568
# Kurtosis: 0.877352

# %%
sns.distplot(dfstar['L']);
# Out:
# C:\Users\Rex Reloaded\anaconda3\envs\virtualenv\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print("Skewness: %f" % df_star['L'].skew())
print("Kurtosis: %f" % df_star['L'].kurt())
# Out:
# Skewness: 2.068069
# Kurtosis: 4.465098

# %%
sns.distplot(dfstar['R']);
# Out:
# C:\Users\Rex Reloaded\anaconda3\envs\virtualenv\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print("Skewness: %f" % df_star['R'].skew())
print("Kurtosis: %f" % df_star['R'].kurt())
# Out:
# Skewness: 1.946800
# Kurtosis: 2.072935

# %%
var = 'L'

# %%
data = pd.concat([df_star['Temperature'], dfstar[var]], axis=1)
data.plot.scatter(x=var, y='Temperature', ylim=(0,40000));
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
var = 'R'

# %%
data = pd.concat([df_star['Temperature'], dfstar[var]], axis=1)
data.plot.scatter(x=var, y='Temperature', ylim=(0,40000));
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
var = 'A_M'

# %%
data = pd.concat([df_star['Temperature'], dfstar[var]], axis=1)
data.plot.scatter(x=var, y='Temperature', ylim=(0,40000));
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
var = 'Type'

# %%
data = pd.concat([df_star['Temperature'], dfstar[var]], axis=1)
fig = sns.boxplot(x=var, y="Temperature", data=data)
fig.axis(ymin=0, ymax=40000);

# %%
dfstar['Spectral_Class'] = dfstar['Spectral_Class'].map({'O': 0, 'B': 1, 'A': 2, 'F': 3, 'G': 4, 'K': 5, 'M': 6}).astype(int)

# %%
var = 'Spectral_Class'

# %%
data = pd.concat([df_star['Temperature'], dfstar[var]], axis=1)
fig = sns.boxplot(x=var, y="Temperature", data=data)
fig.axis(ymin=0, ymax=40000);

# %%
correlationmatrix = dfstar.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(correlationmatrix, vmax=.8, square=True, annot=True);
plt.show()

# %%
sns.set()
cols = ['Temperature', 'L', 'R', 'A_M', 'Spectral_Class', 'Type']
sns.pairplot(dfstar[cols], size = 2.5)
plt.show();
# Out:
# C:\Users\Rex Reloaded\anaconda3\envs\virtualenv\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
print(dfstar.info())
#checking for missing datapoints
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Temperature     240 non-null    int64
#  1   L               240 non-null    float64
#  2   R               240 non-null    float64
#  3   A_M             240 non-null    float64
#  4   Color           240 non-null    object
#  5   Spectral_Class  240 non-null    int32
#  6   Type            240 non-null    int64
# dtypes: float64(3), int32(1), int64(2), object(1)
# memory usage: 12.3+ KB
# None

# %%
star_color = dfstar[["Color"]]

# %%
star_color.head(30)
# Out:
#                  Color
# 0                  Red
# 1                  Red
# 2                  Red
# 3                  Red
# 4                  Red
# 5                  Red
# 6                  Red
# 7                  Red
# 8                  Red
# 9                  Red
# 10                 Red
# 11                 Red
# 12                 Red
# 13                 Red
# 14                 Red
# 15                 Red
# 16                 Red
# 17                 Red
# 18                 Red
# 19                 Red
# 20          Blue White
# 21               White
# 22               White
# 23               White
# 24          Blue White
# 25     Yellowish White
# 26          Blue white
# 27     Yellowish White
# 28     Yellowish White
# 29  Pale yellow orange

# %%
from sklearn.preprocessing import OrdinalEncoder
>>> ordinal_encoder = OrdinalEncoder()
>>> star_color_encoded = ordinal_encoder.fit_transform(star_color)
>>> star_color_encoded[:30]
# Out:
# array([[ 8.],
#        [ 8.],
#        [ 8.],
#        [ 8.],
#        [ 8.],
#        [ 8.],
#        [ 8.],
#        [ 8.],
#        [ 8.],
#        [ 8.],
#        [ 8.],
#        [ 8.],
#        [ 8.],
#        [ 8.],
#        [ 8.],
#        [ 8.],
#        [ 8.],
#        [ 8.],
#        [ 8.],
#        [ 8.],
#        [ 1.],
#        [ 9.],
#        [ 9.],
#        [ 9.],
#        [ 1.],
#        [13.],
#        [ 2.],
#        [13.],
#        [13.],
#        [ 7.]])

# %%
ordinal_encoder.categories_
# Out:
# [array(['Blue', 'Blue White', 'Blue white', 'Blue-White', 'Blue-white',
#         'Orange', 'Orange-Red', 'Pale yellow orange', 'Red', 'White',
#         'White-Yellow', 'Whitish', 'Yellowish', 'Yellowish White', 'white',
#         'yellow-white', 'yellowish'], dtype=object)]

# %%
from sklearn.linear_model import LinearRegression

# %%
Y1=dfstar['Temperature']

# %%
X1=dfstar[['L', 'R', 'A_M', 'Spectral_Class', 'Type']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X1, Y1, test_size = 0.2)

# %%
X_train = sm.add_constant(X_train)
results = sm.OLS(y_train, X_train).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            Temperature   R-squared:                       0.703
# Model:                            OLS   Adj. R-squared:                  0.695
# Method:                 Least Squares   F-statistic:                     88.12
# Date:                Mon, 17 May 2021   Prob (F-statistic):           3.59e-47
# Time:                        05:33:29   Log-Likelihood:                -1918.9
# No. Observations:                 192   AIC:                             3850.
# Df Residuals:                     186   BIC:                             3869.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
X_test = sm.add_constant(X_test)
y_preds = results.predict(X_test)

# %%
plt.figure(dpi = 100)
plt.scatter(y_test, y_preds)
plt.plot(y_test, y_test, color="red")
plt.show()

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(model.coef_)
# Out:
# [ 0.00000000e+00  4.19661303e-03  3.93850263e+00 -5.71093835e+02
#  -3.44866068e+03 -4.54958559e+03]

# %%
print(model.intercept_)
# Out:
# 35012.3501525302

# %%
predictions = model.predict(X_test)

# %%
plt.scatter(y_test, predictions)

# %%
plt.hist(y_test - predictions)
# Out:
# (array([ 1.,  0.,  6., 16., 10., 11.,  2.,  1.,  0.,  1.]),
#  array([-10008.62476038,  -7717.45209262,  -5426.27942486,  -3135.1067571 ,
#           -843.93408933,   1447.23857843,   3738.41124619,   6029.58391395,
#           8320.75658171,  10611.92924948,  12903.10191724]),
#  <BarContainer object of 10 artists>)

# %%
from sklearn.model_selection import cross_val_score
from sklearn import metrics
from sklearn.metrics import classification_report

# %%
metrics.mean_absolute_error(y_test, predictions)
#MAE
# Out:
# 2720.9568739085485

# %%
metrics.mean_squared_error(y_test, predictions)
#MSE
# Out:
# 12693093.647265678

# %%
np.sqrt(metrics.mean_squared_error(y_test, predictions))
#RMSE
# Out:
# 3562.7368198150252

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train,y_train)
y_predz = knn.predict(X_test)
print(metrics.accuracy_score(y_test,y_predz))
# Out:
# 0.0

# %%
Y2=dfstar['R']

# %%
X2=dfstar[['L', 'Temperature', 'A_M', 'Spectral_Class', 'Type']]

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, Y2, test_size = 0.2)

# %%
X2_train = sm.add_constant(X2_train)
results = sm.OLS(y2_train, X2_train).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      R   R-squared:                       0.660
# Model:                            OLS   Adj. R-squared:                  0.651
# Method:                 Least Squares   F-statistic:                     72.31
# Date:                Mon, 17 May 2021   Prob (F-statistic):           9.18e-42
# Time:                        01:50:42   Log-Likelihood:                -1366.0
# No. Observations:                 192   AIC:                             2744.
# Df Residuals:                     186   BIC:                             2764.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
X2_test = sm.add_constant(X2_test)
y2_preds = results.predict(X2_test)

# %%
plt.figure(dpi = 100)
plt.scatter(y2_test, y2_preds)
plt.plot(y2_test, y2_test, color="red")
plt.show()

# %%
model2 = LinearRegression()

# %%
model2.fit(X2_train, y2_train)
# Out:
# LinearRegression()

# %%
print(model2.coef_)
print(model2.intercept_)
# Out:
# [0.00000000e+00 5.82240606e-04 1.24217488e-02 3.03887898e+01
#  1.36163780e+02 3.99598321e+02]
# -1570.49423884933

# %%
predictions2 = model2.predict(X2_test)

# %%
plt.scatter(y2_test, predictions2)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train,y_train)
y_predz = knn.predict(X_test)
print(metrics.accuracy_score(y_test,y_predz))

# %%
Y3=dfstar['Type']
X3=dfstar[['L', 'Temperature', 'A_M', 'Spectral_Class', 'R']]

# %%
X3_train, X3_test, y3_train, y3_test = train_test_split(X3, Y3, test_size = 0.2)

# %%
X3_train = sm.add_constant(X3_train)
results = sm.OLS(y3_train, X3_train).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Type   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.949
# Method:                 Least Squares   F-statistic:                     714.6
# Date:                Mon, 17 May 2021   Prob (F-statistic):          2.44e-119
# Time:                        02:20:25   Log-Likelihood:                -91.247
# No. Observations:                 192   AIC:                             194.5
# Df Residuals:                     186   BIC:                             214.0
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
X3_test = sm.add_constant(X3_test)
y3_preds = results.predict(X3_test)

# %%
plt.figure(dpi = 100)
plt.scatter(y3_test, y3_preds)
plt.plot(y3_test, y3_test, color="red")
plt.show()

# %%
model3 = LinearRegression()

# %%
model3.fit(X3_train, y3_train)
# Out:
# LinearRegression()

# %%
print(model3.coef_)
print(model3.intercept_)
# Out:
# [ 0.00000000e+00 -2.83802488e-07 -2.72577164e-05 -1.30431658e-01
#  -1.89846164e-01  6.95723043e-04]
# 3.898554547189601

# %%
predictions3 = model3.predict(X3_test)

# %%
plt.scatter(y3_test, predictions3)

# %%
metrics.mean_absolute_error(y3_test, predictions3)
#MAE
# Out:
# 0.37248159836889033

# %%
metrics.mean_squared_error(y3_test, predictions3)
#MSE
# Out:
# 0.17291746271920924

# %%
np.sqrt(metrics.mean_squared_error(y3_test, predictions3))
#RMSE
# Out:
# 0.41583345550738127

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(X3_train,y3_train)
y3_pred = knn.predict(X3_test)
print(metrics.accuracy_score(y3_test,y3_pred))
# Out:
# 0.6666666666666666

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=100)
rf.fit(X3_train,y3_train)
# Out:
# RandomForestClassifier()

# %%
print(metrics.accuracy_score(y3_test,y3_pred))
# Out:
# 1.0

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada= AdaBoostClassifier()
ada.fit(X3_train,y3_train)
# Out:
# AdaBoostClassifier()

# %%
y3_pred= ada.predict(X3_test)
print(metrics.accuracy_score(y3_test,y3_pred))
# Out:
# 0.6041666666666666

# %%
from sklearn.ensemble import GradientBoostingClassifier
gradient= GradientBoostingClassifier()
gradient.fit(X3_train,y3_train)
# Out:
# GradientBoostingClassifier()

# %%
y3_pred= gradient.predict(X3_test)
print(metrics.accuracy_score(y3_test,y3_pred))
# Out:
# 1.0

# %%
from sklearn.linear_model import Lasso
 

lasso = Lasso(alpha = 1)
lasso.fit(X3_train, y3_train)
y3_pred1 = lasso.predict(X3_test)
 

mean_squared_error = np.mean((y3_pred1 - y3_test)**2)
print("Mean squared error on test set", mean_squared_error)
lasso_coeff = pd.DataFrame()
lasso_coeff["Columns"] = X3_train.columns
lasso_coeff['Coefficient Estimate'] = pd.Series(lasso.coef_)
#https://www.geeksforgeeks.org/implementation-of-lasso-ridge-and-elastic-net/
 
print(lasso_coeff)
# Out:
# Mean squared error on test set 0.25924742609904033
#           Columns  Coefficient Estimate
# 0           const                 0.000
# 1               L                 0.000
# 2     Temperature                 0.000
# 3             A_M                -0.119
# 4  Spectral_Class                -0.000
# 5               R                 0.001

# %%
Y4=dfstar['Type']
X4=dfstar[['Temperature', 'A_M', 'Spectral_Class', 'R']]

# %%
X4_train, X4_test, y4_train, y4_test = train_test_split(X4, Y4, test_size = 0.2)

# %%
X4_train = sm.add_constant(X4_train)
results = sm.OLS(y4_train, X4_train).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Type   R-squared:                       0.942
# Model:                            OLS   Adj. R-squared:                  0.941
# Method:                 Least Squares   F-statistic:                     759.7
# Date:                Mon, 17 May 2021   Prob (F-statistic):          2.03e-114
# Time:                        05:19:10   Log-Likelihood:                -96.902
# No. Observations:                 192   AIC:                             203.8
# Df Residuals:                     187   BIC:                             220.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
X4_test = sm.add_constant(X4_test)
y4_preds = results.predict(X4_test)

# %%
plt.figure(dpi = 100)
plt.scatter(y4_test, y4_preds)
plt.plot(y4_test, y4_test, color="red")
plt.show()

# %%
model4 = LinearRegression()
model4.fit(X4_train, y4_train)
# Out:
# LinearRegression()

# %%
print(model4.coef_)
print(model4.intercept_)
# Out:
# [ 0.00000000e+00 -2.88161807e-05 -1.23095767e-01 -1.87830371e-01
#   7.08848089e-04]
# 3.8568320476944593

# %%
predictions4 = model4.predict(X4_test)

# %%
plt.scatter(y4_test, predictions4)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X4_train,y4_train)
y4_pred = knn.predict(X4_test)
print(metrics.accuracy_score(y4_test,y4_pred))
# Out:
# 0.6875

# %%
rf=RandomForestClassifier()
rf.fit(X4_train,y4_train)
print(metrics.accuracy_score(y4_test,y4_pred))
# Out:
# 0.6875

# %%
ada= AdaBoostClassifier()
ada.fit(X4_train,y4_train)
y4_pred= ada.predict(X4_test)
print(metrics.accuracy_score(y4_test,y4_pred))
# Out:
# 0.6458333333333334

# %%
gradient= GradientBoostingClassifier()
gradient.fit(X4_train,y4_train)
# Out:
# GradientBoostingClassifier()

# %%
y4_pred= gradient.predict(X4_test)
print(metrics.accuracy_score(y4_test,y4_pred))
# Out:
# 1.0
